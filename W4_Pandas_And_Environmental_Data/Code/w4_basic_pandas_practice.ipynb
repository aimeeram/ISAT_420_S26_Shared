# %% [markdown]
# # Practice: Basic Pandas
#
# In this practice assignment, you will test and review the pandas fundamentals including:
#
# - open csv files
# - manipulate dataframe indexes
# - examine basic dataframe statistics
# - plot dataframe contents using
#     - bar charts
#     - histograms
#     - scatter plots
#
# Data for this assignment in `.csv` format downloaded from the [USGS Earthquakes Database](https://earthquake.usgs.gov/earthquakes/search/).
#
# You don't need to download this file. I have placed it into the `Data` folder for this week. This is the same folder as the `Palmer Penguins` data.

# %% [markdown]
# #### 1) Import pandas and matplotlib
#
# This is similar to how we started our analysis.

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 2) Use Pandas’ read_csv function to open the dataset
#
# (Don’t use any special options). Display the first few rows and the DataFrame info.

# %%
df = pd.read_csv('../Data/usgs_earthquake_data.csv')
df
# Out:
#                           time   latitude   longitude    depth   mag magType  \
# 0     2025-01-01T01:51:40.783Z  38.751200 -119.215000  10.4000  2.60      ml
# 1     2025-01-01T05:57:00.230Z  44.920700  -74.480400   6.2450  2.50   mb_lg
# 2     2025-01-01T07:27:29.330Z  39.427166 -123.285500   6.4300  2.87      md
# 3     2025-01-01T08:42:04.180Z  39.702167 -110.821833  -3.4200  2.54      ml
# 4     2025-01-01T12:24:17.738Z  31.630000 -104.521000   7.0483  2.70      ml
# ...                        ...        ...         ...      ...   ...     ...
# 2549  2025-12-31T05:59:06.730Z  40.533000 -120.676833   6.4300  2.50      md
# 2550  2025-12-31T15:28:39.000Z  38.831500 -122.812000   2.0100  2.88      md
# 2551  2025-12-31T17:19:56.850Z  32.307400 -104.498100   5.4950  2.70      ml
# 2552  2025-12-31T20:44:09.540Z  44.664167 -110.678333   7.4000  2.71      ml
# 2553  2025-12-31T23:24:31.670Z  40.489833 -124.793167  22.3100  2.74      md
#
#       nst     gap      dmin     rms  ...                   updated  \
# 0      26   38.71  0.135000  0.1378  ...  2025-03-17T21:33:58.040Z
# 1      19   79.00  0.310000  0.5700  ...  2025-03-17T21:34:00.040Z
# 2      41   45.00  0.057980  0.0900  ...  2025-03-17T21:34:01.040Z
# 3      31   46.00  0.067370  0.1900  ...  2025-03-17T21:34:01.040Z
# 4       8   75.00  0.000000  0.3000  ...  2025-03-17T21:34:03.040Z
# ...   ...     ...       ...     ...  ...                       ...
# 2549   25   61.00  0.095200  0.1300  ...  2026-01-10T23:32:21.129Z
# 2550  108   21.00  0.008232  0.0800  ...  2026-01-23T02:11:48.040Z
# 2551   29   88.00  0.526000  0.2000  ...  2026-01-22T17:00:15.040Z
# 2552   27   43.00  0.048630  0.1800  ...  2026-01-14T17:57:11.040Z
# 2553   67  236.00  0.338700  0.1600  ...  2026-01-27T04:37:24.040Z
#
#                                             place        type horizontalError  \
# 0                      11 km ESE of Smith, Nevada  earthquake             NaN
# 1     6 km SSE of Fort Covington Hamlet, New York  earthquake        1.770000
# 2                           6 km E of Willits, CA  earthquake        0.160000
# 3                     2 km NW of Kenilworth, Utah  earthquake        0.270000
# 4            62 km SSW of Whites City, New Mexico  earthquake        3.098379
# ...                                           ...         ...             ...
# 2549                  13 km NNW of Susanville, CA  earthquake        0.210000
# 2550                   8 km NW of The Geysers, CA  earthquake        0.080000
# 2551          18 km NW of Whites City, New Mexico  earthquake        2.310000
# 2552         33 km E of West Yellowstone, Montana  earthquake        0.280000
# 2553                    46 km WSW of Ferndale, CA  earthquake        0.770000
#
#      depthError  magError  magNst     status  locationSource magSource
# 0      1.300000  0.240000     9.0   reviewed              nn        nn
# 1      6.132000  0.255000     4.0   reviewed              us        us
# 2      0.630000  0.140000    50.0  automatic              nc        nc
# 3      0.800000  0.178676    18.0   reviewed              uu        uu
# 4      1.757224  0.100000    25.0   reviewed              tx        tx
# ...         ...       ...     ...        ...             ...       ...
# 2549   0.590000  0.162000    30.0   reviewed              nc        nc
# 2550   0.130000  0.172000   150.0   reviewed              nc        nc
# 2551   5.746000  0.060000    70.0   reviewed              us        us
# 2552   0.450000  0.305699    11.0   reviewed              uu        uu
# 2553   1.760000  0.316000    44.0   reviewed              nc        nc
#
# [2554 rows x 22 columns]

# %% [markdown]
# #### 3) Getting a basic overview of the data
#
# - Use `.info` to learn more about the columns
# - Use `.describe()` to get basic descriptive statistics

# %%
df.info
df.describe()
# Out:
#           latitude    longitude        depth          mag          nst  \
# count  2554.000000  2554.000000  2554.000000  2554.000000  2554.000000
# mean     37.435279  -112.518324     8.019383     2.907459    47.725137
# std       4.797979     9.351118     6.051866     0.408322    37.073260
# min      24.814900  -124.996667    -3.420000     2.500000     4.000000
# 25%      32.473275  -119.563875     5.000000     2.600000    21.000000
# 50%      37.456083  -115.606167     7.074000     2.800000    36.000000
# 75%      41.059075  -104.411875    10.000000     3.100000    64.000000
# max      49.692800   -68.868900    68.340000     5.600000   228.000000
#
#                gap         dmin          rms  horizontalError   depthError  \
# count  2554.000000  2551.000000  2554.000000      2248.000000  2554.000000
# mean     87.348500     0.267163     0.269053         1.288548     2.087783
# std      64.060496     0.350577     0.216100         1.754498     3.875910
# min      11.000000     0.000000     0.000000         0.060000     0.000000
# 25%      46.000000     0.038070     0.130000         0.220000     0.480251
# 50%      67.000000     0.111800     0.200000         0.590000     0.916836
# 75%     111.000000     0.336000     0.300000         1.530000     1.945000
# max     358.180000     4.014000     1.370000        11.800000    31.610000
#
#           magError       magNst
# count  2428.000000  2517.000000
# mean      0.149114    56.330950
# std       0.085087    61.304607
# min       0.000000     0.000000
# 25%       0.097000    17.000000
# 50%       0.143000    34.000000
# 75%       0.200000    75.000000
# max       0.600000   447.000000

# %% [markdown]
# #### 4) Assign data to a new column
#
# Examine the `place` column. There is information about the location (U.S. State) in there.
#
# Using [pandas string methods](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html) we can extract the information about the U.S. State. The piece of code below, will split the text in each column at the `","` and then return the second element (python starts counting at 0) as a series.
#
# `df['place'].str.split(',').str.get(1)`
#
# You can look this up in the documentation, but you don't need to know how to do this.
#
# Assign this series to a new column in your dataframe called: `state`

# %%
df['state']=df['place'].str.split(',').str.get(1)

# %% [markdown]
# #### 5) Get unique values for the new column
#
# Use the [`.unique()` method](https://pandas.pydata.org/docs/reference/api/pandas.Series.unique.html) to display all the unique values for this new column
#
# What do you notice and what does this mean for working with the dataset

# %%
df['state'].unique()
# Out:
# array([' Nevada', ' New York', ' CA', ' Utah', ' New Mexico', ' Montana',
#        ' Texas', ' Nebraska', ' Wyoming', ' Arkansas', ' B.C.',
# 1183     mwr  112   27.00  0.125000  0.6800  ...
# 1224      mw  185  230.00  0.414200  0.3000  ...
# 1327      mb   41  124.00  0.670000  0.9500  ...
# 1331      mw   65   69.00  0.301300  0.1000  ...
# 1416      mw   79   41.00  0.024210  0.2500  ...
# 1484      mb   60  201.00  1.748000  1.0900  ...
# 1529      mw  159   16.00  0.045800  0.2300  ...
# 1600      mw  127   20.00  0.012960  0.0800  ...
# 1622     mww   53  139.00  2.306000  0.8400  ...
# 1698      mw    9  138.73  1.186000  0.4162  ...
# 1742      mb   39   86.00  0.477000  1.2600  ...
# 1825      ml   25  105.00  0.121300  0.2700  ...
# 1892      mw  177   12.00  0.011870  0.1300  ...
# 2023      ml   21   55.00  0.200000  0.1000  ...
# 2165      mb   23  179.00  0.576000  1.1500  ...
# 2185      mb   35  117.00  0.656000  0.6700  ...
# 2186      mb   44  158.00  4.014000  0.7700  ...
# 2187     mww  136   63.00  0.652000  0.8300  ...
# 2193      mb   38  123.00  0.620000  1.2900  ...
# 2194     mww   77   54.00  0.684000  0.4600  ...
# 2195      mb   57  110.00  0.647000  0.8000  ...
# 2196     mww  107  122.00  0.645000  0.4100  ...
# 2271      mw   67   46.00  0.053610  0.0900  ...
# 2319      mw  121   29.00  0.024990  0.2000  ...
# 2428      mw  181   16.00       NaN  0.1600  ...
# 2536      mw   30   61.00  0.080670  0.1400  ...
# 2548      mw   29   62.00  0.085130  0.1600  ...
#
#                                               place        type  \
# 21                              4 km NW of Cobb, CA  earthquake
# 58               56 km S of Whites City, New Mexico  earthquake
# 166                      18 km W of Delta, B.C., MX  earthquake
# 181                       56 km WNW of Petrolia, CA  earthquake
# 192                      26 km NW of Clayton, Idaho  earthquake
# 209                  18 km ENE of Falls City, Texas  earthquake
# 280                         26 km W of Petrolia, CA  earthquake
# 308                         10 km NNW of Avenal, CA  earthquake
# 316                        53 km NW of Toyah, Texas  earthquake
# 346            52 km SSW of Whites City, New Mexico  earthquake
# 372                     28 km W of Squamish, Canada  earthquake
# 428                      26 km SW of Ackerly, Texas  earthquake
# 445              51 km S of Whites City, New Mexico  earthquake
# 452                   2025 Orcas Island, Washington  earthquake
# 483                          10 km NW of Malibu, CA  earthquake
# 530                  9 km NNE of Lake Pillsbury, CA  earthquake
# 746                            5 km S of Julian, CA  earthquake
# 811                       56 km WNW of Petrolia, CA  earthquake
# 874              59 km S of Whites City, New Mexico  earthquake
# 925                21 km SE of Greenback, Tennessee  earthquake
# 934         13 km E of Ciudad General Terán, Mexico  earthquake
# 1016                        33 km W of Petrolia, CA  earthquake
# 1023                        31 km W of Petrolia, CA  earthquake
# 1134                     56 km NW of Ocampo, Mexico  earthquake
# 1183                      24 km E of Clayton, Idaho  earthquake
# 1224                      51 km WNW of Petrolia, CA  earthquake
# 1327             74 km NNE of Santa Rosalía, Mexico  earthquake
# 1331                   8 km SSE of Deep Springs, CA  earthquake
# 1416                    12 km WNW of Calipatria, CA  earthquake
# 1484                   8 km ENE of Culiacán, Mexico  earthquake
# 1529                          6 km NW of Rialto, CA  earthquake
# 1600                     6 km NW of The Geysers, CA  earthquake
# 1622  92 km W of Las Grullas Margen Derecha, Mexico  earthquake
# 1698                      51 km NE of Valmy, Nevada  earthquake
# 1742               64 km ENE of San Vicente, Mexico  earthquake
# 1825                        10 km W of Maeser, Utah  earthquake
# 1892                       2 km ESE of Berkeley, CA  earthquake
# 2023                   5 km WSW of Westbrook, Texas  earthquake
# 2165                63 km SW of Topolobampo, Mexico  earthquake
# 2185              72 km NE of Santa Rosalía, Mexico  earthquake
# 2186             78 km NNE of Santa Rosalía, Mexico  earthquake
# 2187             71 km NNE of Santa Rosalía, Mexico  earthquake
# 2193              68 km NE of Santa Rosalía, Mexico  earthquake
# 2194             75 km NNE of Santa Rosalía, Mexico  earthquake
# 2195             71 km NNE of Santa Rosalía, Mexico  earthquake
# 2196             70 km NNE of Santa Rosalía, Mexico  earthquake
# 2271                        7 km W of Templeton, CA  earthquake
# 2319                5 km S of San Juan Bautista, CA  earthquake
# 2428                       6 km W of Glen Ellen, CA  earthquake
# 2536                    15 km NNW of Susanville, CA  earthquake
# 2548                    15 km NNW of Susanville, CA  earthquake
#
#      horizontalError depthError  magError  magNst    status  locationSource  \
# 21          0.090000   0.150000       NaN    21.0  reviewed              nc
# 58          0.778876   0.928857  0.200000    21.0  reviewed              tx
# 166         0.450000   0.930000  0.139000   183.0  reviewed              ci
# 181         0.700000   1.030000       NaN     7.0  reviewed              nc
# 192         2.220000   5.392000  0.026000   146.0  reviewed              us
# 209         0.584432   0.740967  0.100000    26.0  reviewed              tx
# 280         0.990000   0.420000       NaN    10.0  reviewed              nc
# 308         0.150000   0.220000  0.145000   160.0  reviewed              nc
# 316         0.634105   1.011025  0.100000    10.0  reviewed              tx
# 346         0.598032   1.122082  0.100000    18.0  reviewed              tx
# 372         3.690000   1.900000  0.052000    35.0  reviewed              us
# 428         0.489008   1.494629  0.200000    45.0  reviewed              tx
# 445         0.617898   0.667356  0.200000    33.0  reviewed              tx
# 452         0.140000   0.220000  0.201125   204.0  reviewed              uw
# 483         0.290000   0.390000       NaN     4.0  reviewed              ci
# 530         0.130000   0.310000       NaN    15.0  reviewed              nc
# 746         0.120000   0.300000       NaN     6.0  reviewed              ci
# 811         0.650000   1.020000       NaN     6.0  reviewed              nc
# 874         2.013516   0.633207  0.100000    35.0  reviewed              tx
# 925         0.250000   0.420000       NaN     0.0  reviewed              se
# 934         4.110000   5.243000  0.078000    46.0  reviewed              us
# 1016        0.620000   0.800000       NaN     6.0  reviewed              nc
# 1023        0.530000   0.900000       NaN    12.0  reviewed              nc
# 1134        4.130000   1.846000  0.063000    24.0  reviewed              us
# 1183        4.580000   2.162000  0.031000   101.0  reviewed              us
# 1224        0.470000   0.740000       NaN    14.0  reviewed              nc
# 1327        5.940000   1.955000  0.055000    90.0  reviewed              us
# 1331        0.230000   0.570000       NaN    12.0  reviewed              nc
# 1416        0.200000   0.470000       NaN     6.0  reviewed              ci
# 1484        6.530000   1.972000  0.060000    78.0  reviewed              us
# 1529        0.120000   0.310000       NaN    10.0  reviewed              ci
# 1600        0.080000   0.110000       NaN     7.0  reviewed              nc
# 1622        6.590000   1.844000  0.043000    52.0  reviewed              us
# 1698             NaN  15.800000       NaN     NaN  reviewed              nn
# 1742        1.460000   1.846000  0.091000    34.0  reviewed              us
# 1825        0.810000   2.340000  0.117386    35.0  reviewed              uu
# 1892        0.090000   0.160000       NaN    52.0  reviewed              nc
# 2023        0.559136   2.233681  0.100000    25.0  reviewed              tx
# 2165        6.740000   1.938000  0.120000    19.0  reviewed              us
# 2185        4.970000   1.927000  0.076000    50.0  reviewed              us
# 2186        8.130000   1.901000  0.044000   157.0  reviewed              us
# 2187        5.160000   1.884000  0.050000    39.0  reviewed              us
# 2193        6.040000   1.910000  0.102000    28.0  reviewed              us
# 2194        5.220000   2.437000  0.032000    91.0  reviewed              us
# 2195        4.150000   1.895000  0.074000    57.0  reviewed              us
# 2196        6.620000   1.942000  0.054000    33.0  reviewed              us
# 2271        0.160000   0.460000       NaN    23.0  reviewed              nc
# 2319        0.150000   0.230000       NaN    14.0  reviewed              nc
# 2428        0.100000   0.250000       NaN    48.0  reviewed              nc
# 2536        0.250000   0.720000       NaN    95.0  reviewed              nc
# 2548        0.230000   0.840000       NaN    20.0  reviewed              nc
#
#       magSource        state
# 21           nc           CA
# 58           tx   New Mexico
# 166          ci         B.C.
# 181          nc           CA
# 192          us        Idaho
# 209          tx        Texas
# 280          nc           CA
# 308          nc           CA
# 316          tx        Texas
# 346          tx   New Mexico
# 372          us       Canada
# 428          tx        Texas
# 445          tx   New Mexico
# 452          uw   Washington
# 483          ci           CA
# 530          nc           CA
# 746          ci           CA
# 811          nc           CA
# 874          tx   New Mexico
# 925          se    Tennessee
# 934          us       Mexico
# 1016         nc           CA
# 1023         nc           CA
# 1134         us       Mexico
# 1183         us        Idaho
# 1224         nc           CA
# 1327         us       Mexico
# 1331         nc           CA
# 1416         ci           CA
# 1484         us       Mexico
# 1529         ci           CA
# 1600         nc           CA
# 1622         us       Mexico
# 1698         nn       Nevada
# 1742         us       Mexico
# 1825         uu         Utah
# 1892         nc           CA
# 2023         tx        Texas
# 2165         us       Mexico
# 2185         us       Mexico
# 2186         us       Mexico
# 2187         us       Mexico
# 2193         us       Mexico
# 2194         us       Mexico
# 2195         us       Mexico
# 2196         us       Mexico
# 2271         nc           CA
# 2319         nc           CA
# 2428         nc           CA
# 2536         nc           CA
# 2548         nc           CA
#
# [51 rows x 23 columns]

# %% [markdown]
# #### 7) Make a histogram
#
# Make a histogram the distribution of the Earthquake magnitudes
#
# Use the plotting functionality to create a histogram for the magnitude column of the complete dataset.
#
# The pandas plotting methods use `matplotlib` as a basis. Look up in the [histogram documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html) how to set the y-axis to logarithmic.
#
# Give the plot labels and titles to make it nicer.

# %%
df['mag'].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### 8) Visualize earthquake locations
#
# Create two plots, one for the filtered and non-filtered dataset each.
#
# Visualize the locations of earthquakes by making a scatterplot of their latitude and longitude.
#
# See whether you can use the [scatter documentation](matplotlib.pyplot.scatter) to figure out how to color the points by magnitude.
#
# What difference do you note between the filtered and unfiltered datasets?

# %%
df.plot(kind='scatter', x='latitude', y='longitude', grid=True)
adults.plot(kind='scatter', x='latitude', y='longitude', grid= True)
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %% [markdown]
# #### Make a bar plot of earthquake locations
#
# Get the value counts for the `state` column and create a bar plot with the earthquake count on the y-axis and the location on the x-axis.

# %%
df['state'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='state'>
